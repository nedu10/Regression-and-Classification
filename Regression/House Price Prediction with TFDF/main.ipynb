# %% [markdown]
# # House Price Prediction With TensorFlow Decision Forest

# %%
# !pip3 install tensorflow_decision_forests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import tensorflow_decision_forests as tfdf
import pandas as pd
# Out:
# 2024-07-09 16:18:30.904687: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-09 16:18:31.009416: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 16:18:31.060185: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 16:18:31.060487: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
train_data = pd.read_csv('./data/train.csv')
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
tf_train_data = tfdf.keras.pd_dataframe_to_tf_dataset(train_data, label="SalePrice")
tf_train_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tf_train_data = tfdf.keras.pd_dataframe_to_tf_dataset(train_data, label="SalePrice")
#       2 tf_train_data
#
# File ~/.local/lib/python3.10/site-packages/tensorflow_decision_forests/keras/core_inference.py:1100, in pd_dataframe_to_tf_dataset(dataframe, label, task, max_num_classes, in_place, fix_feature_names, weight, batch_size)
#    1098 classification_classes = list(dataframe[label].unique())
#    1099 if len(classification_classes) > max_num_classes:
# -> 1100   raise ValueError(
#    1101       f"The number of unique classes ({len(classification_classes)}) "
#    1102       f"exceeds max_num_classes ({max_num_classes}). A high number of "
#    1103       "unique value / classes might indicate that the problem is a "
#    1104       "regression or a ranking instead of a classification. If this "
# ...
